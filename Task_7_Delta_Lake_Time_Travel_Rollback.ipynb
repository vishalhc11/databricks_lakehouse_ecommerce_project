# %%
# %sql
use catalog main;
use schema ecommerce;

# %%
# %sql
select * from customer limit 1;

# %%
# %sql
drop table customer_version;

# %%
# %sql
create or replace table customer_version as
select * from customer where customer_id='f6aa4b1360cc4c6186561ebc2caf14bc';

# %%
# %sql
select * from customer_version;

# %%
# %sql
update customer_version 
set customer_city = 'Patna',
    customer_state = 'BH'
where customer_id='f6aa4b1360cc4c6186561ebc2caf14bc';

# %%
# %sql
select * from customer_version Version as of 0;

# %%
# %sql
select * from main.ecommerce.customer_version where customer_id = "f6aa4b1360cc4c6186561ebc2caf14bc"
